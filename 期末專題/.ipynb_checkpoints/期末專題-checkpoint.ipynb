# %%
import requests

def search_nearby_places(api_key, location, keyword):
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "key": api_key,
        "location": location,
        "radius": "2000",
        "keyword": keyword
    }

    response = requests.get(url, params=params)
    data = response.json()
    print(params)
    print(data)

    if data["status"] == "OK":
        results = data["results"]
        for place in results:
            name = place["name"]
            address = place["vicinity"]
            # print(f"Name: {name}\nAddress: {address}\n")
            
keyfile = open("key.txt", "r")
key = keyfile.readline()
key = keyfile.readline()

api_key = key
location = "25.013413,121.540475"
keyword = "咖啡廳"

search_nearby_places(api_key, location, keyword)
# Out:
# {'key': 'AIzaSyDMNGD8UwLzdAVMuMKWLNUZW8hGl5fjEvk', 'location': '25.013413,121.540475', 'radius': '2000', 'keyword': '咖啡廳'}
# {'html_attributions': [], 'next_page_token': 'AZose0lVG7gfHtKPdRc8GcK1QGj1f_n2cPGThNtcBFhjLwskMXY0zET0pzZj6jPcaufJAN3bvk4C2ZeTei4oWKmT00Nq09uKdAJu-YXyqNFzXbvWwyc-UJDD-RiTaTZFtoHuBIYC5_rhg5qWOxP8g_vP0YskU7bdh-wTAEmZ2KMs6ANRrPvb6-2o2IpDAqs2qzA-BoXEhKp0E0JDE41_BRiqXYL9HhV9hPo-HjQz3qH6bXN-Bh_0RCI-9cwvnZ5X2T9tbSTQprvIkHe5ihA-lWVNrzKIv_MbDK_xejhGHGsdYbwflr7u0yqUlF12ZtAaXc_BZIjyxWfbG-JjvI8itSYMskTriSPpRCpkYqtkaKM8E5vh-aMrDXoP-Ya-KBeAgZPW3qAFAQdVjVU3ShEHUuYMCV49DiEB5xkzZisFECVqzhdaGXYfTQw4QpLmUis', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 25.0273704, 'lng': 121.54016}, 'viewport': {'northeast': {'lat': 25.02871477989272, 'lng': 121.5415186298927}, 'southwest': {'lat': 25.02601512010728, 'lng': 121.5388189701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet', 'name': 'The Quiet Light 默光咖啡（瑞安店）', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3456, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108334386608969326011">A Google User</a>'], 'photo_reference': 'AZose0neszrANNM29GDLtaF0bx7fvbCUMATH3CbSDbGzB60hw-x3etUOjkiLrMzpAcn4ZoSEE2Ck14F7NdbH3RfxEKyoEarr8e5E4uU-c_ekXyrqVr2xiycc87aaoohOgtRaZhRemeWGK8rSR1kABN6ns_ae8jBWONIVdbF4EbV0g_IkHsUS', 'width': 5184}], 'place_id': 'ChIJDXMcF5CrQjQRam-vMjrTO2E', 'plus_code': {'compound_code': '2GGR+W3 Da’an District, Taipei City', 'global_code': '7QQ32GGR+W3'}, 'rating': 4.7, 'reference': 'ChIJDXMcF5CrQjQRam-vMjrTO2E', 'scope': 'GOOGLE', 'types': ['cafe', 'store', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 224, 'vicinity': "No. 111號, Rui'an St, Da’an District"}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 25.0257181, 'lng': 121.5312209}, 'viewport': {'northeast': {'lat': 25.02714132989272, 'lng': 121.5325746298927}, 'southwest': {'lat': 25.02444167010728, 'lng': 121.5298749701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet', 'name': 'Young Coffee', 'opening_hours': {'open_now': False}, 'photos': [{'height': 2608, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105651810024921045077">葉和鑫</a>'], 'photo_reference': 'AZose0nxbBnSPwC8L-ZnSayqKp02sOxPbdWfAkt83J8XoC_k7J_5AvT5kXYBjKTCLwsk11DrYDBIpKmaZqbbQRnF0ISjVF1Unw1Nq_LSU5hji5VPOOU7tugwUSaSXZ6vjZIMOP1tQyEaXw0fe8lUEdvqR1rBIOYVH8NyZHaCJHWLE1_7rWQ', 'width': 4624}], 'place_id': 'ChIJmea4sBCpQjQRolGUWnmNKuo', 'plus_code': {'compound_code': '2GGJ+8F Da’an District, Taipei City', 'global_code': '7QQ32GGJ+8F'}, 'price_level': 1, 'rating': 4.9, 'reference': 'ChIJmea4sBCpQjQRolGUWnmNKuo', 'scope': 'GOOGLE', 'types': ['cafe', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 325, 'vicinity': 'No. 4號, Lane 2, Taishun St, Da’an District'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 25.0006364, 'lng': 121.5276768}, 'viewport': {'northeast': {'lat': 25.00198702989272, 'lng': 121.5290264798927}, 'southwest': {'lat': 24.99928737010728, 'lng': 121.5263268201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet', 'name': '夏班納咖啡館-永和精品咖啡廳｜不限時咖啡廳｜虹吸咖啡｜手作甜點｜手作課', 'opening_hours': {'open_now': True}, 'photos': [{'height': 1365, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105431828400142620658">amelie</a>'], 'photo_reference': 'AZose0ku_6xq8HpSKT7tLeu6uXyj58EOji176t4T2woYZlU28RqT2hhl-BXZMgSm-CJhfAL0QylQG2SAiYHXT6iLGzkyRvQK9kcZXbpD-NkSCBLtMlu6mG3CXKv1v84Ff6zoH9l1OWRUBRe6-kMC1-JIzviVwgWzocQMBfMh5-ArKaFJ7n5U', 'width': 2048}], 'place_id': 'ChIJW8YfM6CpQjQRrwFDLlTqgHk', 'plus_code': {'compound ...

# %%
import tkinter as tk
import requests

keyfile = open("key.txt", "r")
key = keyfile.readline()
key = keyfile.readline()

api_key = key
location = "25.013413,121.540475"
keyword = "咖啡廳"

def search_nearby_places():

    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "key": api_key,
        "location": location,
        "radius": "2000",
        "keyword": keyword,
        "language": "zh-TW"
    }

    response = requests.get(url, params=params)
    data = response.json()

    results_listbox.delete(0, tk.END) # 刪除上一次的結果

    if data["status"] == "OK":
        results = data["results"]
        for place in results:
            name = place["name"]
            address_components = place["plus_code"]["compound_code"].split()
            county = [c for c in address_components if "縣" in c or "市" in c][0]
            address = place["vicinity"].replace(county, "")
            results_listbox.insert(tk.END, f"Name: {name}\n")
            results_listbox.insert(tk.END, f"Address: {county}{address}\n")
            results_listbox.insert(tk.END, "\n")
    else:
        results_listbox.insert(tk.END, "No results found.")

# 建立使用者介面
root = tk.Tk()
root.title("Nearby Places Search")

# 建立位置和關鍵字輸入框
location_label = tk.Label(root, text="Location:")
location_label.grid(row=0, column=0, padx=5, pady=5)
location_entry = tk.Entry(root, width=40)
location_entry.grid(row=0, column=1, padx=5, pady=5)
location_entry.insert(0, "National Taiwan Normal University")

keyword_label = tk.Label(root, text="Keyword:")
keyword_label.grid(row=1, column=0, padx=5, pady=5)
keyword_entry = tk.Entry(root, width=40)
keyword_entry.grid(row=1, column=1, padx=5, pady=5)
keyword_entry.insert(0, "Coffee Shop")

# 建立搜尋按鈕
search_button = tk.Button(root, text="Search", command=search_nearby_places)
search_button.grid(row=2, column=0, columnspan=2, padx=5, pady=5)

# 建立結果列表框架
results_frame = tk.Frame(root)
results_frame.grid(row=3, column=0, columnspan=2, padx=5, pady=5)

# 建立結果列表
results_listbox = tk.Listbox(results_frame, width=60, height=15)
results_listbox.pack(side=tk.LEFT, fill=tk.BOTH)
results_scrollbar = tk.Scrollbar(results_frame, orient=tk.VERTICAL, command=results_listbox.yview)
results_scrollbar.pack(side=tk.RIGHT, fill=tk.Y)
results_listbox.config(yscrollcommand=results_scrollbar.set)

# 啟動使用者介面
root.mainloop()
