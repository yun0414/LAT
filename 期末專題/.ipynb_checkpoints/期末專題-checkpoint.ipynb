# %%
import tkinter as tk
import requests

keyfile = open("key.txt", "r")
key = keyfile.readline()
key = keyfile.readline()

api_key = key

def geocode_address(address):
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {
        "address": address,
        "key": api_key
    }

    response = requests.get(url, params=params)
    data = response.json()

    if data["status"] == "OK":
        results = data["results"]
        location = results[0]["geometry"]["location"]
        latitude = location["lat"]
        longitude = location["lng"]
        return f"{latitude}, {longitude}"
    else:
        print("無法獲取座標。")
    
        
def calculate_distance(lat1, lon1, lat2, lon2):
    """
    使用 Haversine 公式計算兩組座標之間的距離。
    """
    from math import radians, sin, cos, sqrt, atan2

    # 地球半徑，單位為公里
    R = 6371.0

    lat1_rad = radians(lat1)
    lon1_rad = radians(lon1)
    lat2_rad = radians(lat2)
    lon2_rad = radians(lon2)

    dlon = lon2_rad - lon1_rad
    dlat = lat2_rad - lat1_rad

    a = sin(dlat / 2) ** 2 + cos(lat1_rad) * cos(lat2_rad) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

def search_nearby_places():
    keyword = keyword_entry.get()  # 從使用者輸入中獲取關鍵字
    address = location_entry.get()
    location = geocode_address(address)

    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "key": api_key,
        "location": location,
        "radius": "2000",
        "keyword": keyword,
        "language": "zh-TW"
    }

    response = requests.get(url, params=params)
    data = response.json()

    results_listbox.delete(0, tk.END)  # 清除先前的搜尋結果

    if data["status"] == "OK":
        results = data["results"]
        landmark_lat, landmark_lon = map(float, location.split(","))
        
        # 建立一個列表來存儲帶有距離的搜尋結果
        results_with_distance = []
        
        for place in results:
            name = place["name"]
            address_components = place["plus_code"]["compound_code"].split()
            county = [c for c in address_components if "縣" in c or "市" in c][0]
            address = county + place["vicinity"].replace(county, "")
            place_lat = place["geometry"]["location"]["lat"]
            place_lon = place["geometry"]["location"]["lng"]
            distance = calculate_distance(landmark_lat, landmark_lon, place_lat, place_lon)
            rating = place.get("rating", "N/A")  # 檢查是否有評分，若無則設為 "N/A"
            price_level = place.get("price_level", "N/A")
            
            # 將帶有距離的搜尋結果加入列表
            results_with_distance.append((name, address, distance, rating, price_level))
        
        # 根據距離對結果進行排序
        sorted_results = sorted(results_with_distance, key=lambda x: x[2])
        return sorted_results
        
    else:
        results_listbox.insert(tk.END, f"沒有搜尋結果")
        
def result():
    sorted_results = search_nearby_places()
    for result in sorted_results:
        name = result[0]
        address = result[1]
        distance = result[2]
        rating = result[3]
        price = result[4]
        
        # 在結果列表中顯示店名、地址、距離和評分
        results_listbox.insert(tk.END, f"店名: {name}\n")
        results_listbox.insert(tk.END, f"地址: {address}\n")
        results_listbox.insert(tk.END, f"距離: {distance:.2f} 公里\n")
        results_listbox.insert(tk.END, f"評分: {rating} 顆星星\n")
        results_listbox.insert(tk.END, f"價格: {price} \n")
        results_listbox.insert(tk.END, "\n")

def rating_45():
    sorted_results = search_nearby_places()
    for result in sorted_results:
        name = result[0]
        address = result[1]
        distance = result[2]
        rating = result[3]
        price = result[4]
        
        if rating >=4.5:
            # 在結果列表中顯示店名、地址、距離和評分
            results_listbox.insert(tk.END, f"店名: {name}\n")
            results_listbox.insert(tk.END, f"地址: {address}\n")
            results_listbox.insert(tk.END, f"距離: {distance:.2f} 公里\n")
            results_listbox.insert(tk.END, f"評分: {rating} 顆星星\n")
            results_listbox.insert(tk.END, f"價格: {price} \n")
            results_listbox.insert(tk.END, "\n")
            
def rating_40():
    sorted_results = search_nearby_places()
    for result in sorted_results:
        name = result[0]
        address = result[1]
        distance = result[2]
        rating = result[3]
        price = result[4]
        
        if rating >=4.0:
            # 在結果列表中顯示店名、地址、距離和評分
            results_listbox.insert(tk.END, f"店名: {name}\n")
            results_listbox.insert(tk.END, f"地址: {address}\n")
            results_listbox.insert(tk.END, f"距離: {distance:.2f} 公里\n")
            results_listbox.insert(tk.END, f"評分: {rating} 顆星星\n")
            results_listbox.insert(tk.END, f"價格: {price} \n")
            results_listbox.insert(tk.END, "\n")

def rating_35():
    sorted_results = search_nearby_places()
    for result in sorted_results:
        name = result[0]
        address = result[1]
        distance = result[2]
        rating = result[3]
        price = result[4]
        
        if rating >=3.5:
            # 在結果列表中顯示店名、地址、距離和評分
            results_listbox.insert(tk.END, f"店名: {name}\n")
            results_listbox.insert(tk.END, f"地址: {address}\n")
            results_listbox.insert(tk.END, f"距離: {distance:.2f} 公里\n")
            results_listbox.insert(tk.END, f"評分: {rating} 顆星星\n")
            results_listbox.insert(tk.END, f"價格: {price} \n")
            results_listbox.insert(tk.END, "\n")

def price_1():
    sorted_results = search_nearby_places()
    for result in sorted_results:
        name = result[0]
        address = result[1]
        distance = result[2]
        rating = result[3]
        price = result[4]
        
        if price ==1:
            # 在結果列表中顯示店名、地址、距離和評分
            results_listbox.insert(tk.END, f"店名: {name}\n")
            results_listbox.insert(tk.END, f"地址: {address}\n")
            results_listbox.insert(tk.END, f"距離: {distance:.2f} 公里\n")
            results_listbox.insert(tk.END, f"評分: {rating} 顆星星\n")
            results_listbox.insert(tk.END, f"價格: {price} \n")
            results_listbox.insert(tk.END, "\n")

def price_2():
    sorted_results = search_nearby_places()
    for result in sorted_results:
        name = result[0]
        address = result[1]
        distance = result[2]
        rating = result[3]
        price = result[4]
        
        if price ==2:
            # 在結果列表中顯示店名、地址、距離和評分
            results_listbox.insert(tk.END, f"店名: {name}\n")
            results_listbox.insert(tk.END, f"地址: {address}\n")
            results_listbox.insert(tk.END, f"距離: {distance:.2f} 公里\n")
            results_listbox.insert(tk.END, f"評分: {rating} 顆星星\n")
            results_listbox.insert(tk.END, f"價格: {price} \n")
            results_listbox.insert(tk.END, "\n")
            
def price_3():
    sorted_results = search_nearby_places()
    for result in sorted_results:
        name = result[0]
        address = result[1]
        distance = result[2]
        rating = result[3]
        price = result[4]
        
        if price ==3:
            # 在結果列表中顯示店名、地址、距離和評分
            results_listbox.insert(tk.END, f"店名: {name}\n")
            results_listbox.insert(tk.END, f"地址: {address}\n")
            results_listbox.insert(tk.END, f"距離: {distance:.2f} 公里\n")
            results_listbox.insert(tk.END, f"評分: {rating} 顆星星\n")
            results_listbox.insert(tk.END, f"價格: {price} \n")
            results_listbox.insert(tk.END, "\n")
        
# 建立使用者介面
root = tk.Tk()
root.title("附近地點搜尋")

# 建立評分篩選按鈕容器
rating_buttons_frame = tk.Frame(root)
rating_buttons_frame.pack(padx=5, pady=5, anchor="w")

# 建立位置和關鍵字輸入欄位
location_label = tk.Label(rating_buttons_frame, text="位置:")
location_label.pack(side=tk.LEFT, padx=28, pady=5, anchor="w")
location_entry = tk.Entry(rating_buttons_frame, width=40)
location_entry.pack(padx=5, pady=5, anchor="w")
location_entry.insert(0, "國立臺灣師範大學")

rating_buttons_frame = tk.Frame(root)
rating_buttons_frame.pack(padx=5, pady=5, anchor="w")

keyword_label = tk.Label(rating_buttons_frame, text="關鍵字:")
keyword_label.pack(side=tk.LEFT, padx=21, pady=5, anchor="w")
keyword_entry = tk.Entry(rating_buttons_frame, width=40)
keyword_entry.pack(padx=5, pady=5, anchor="w")
keyword_entry.insert(0, "想找什麼呢")

# 建立搜尋按鈕容器
rating_buttons_frame = tk.Frame(root)
rating_buttons_frame.pack(padx=5, pady=5, anchor="w")

# 建立搜尋按鈕
location_label = tk.Label(rating_buttons_frame, text="搜尋:")
location_label.pack(side=tk.LEFT, padx=27, pady=5, anchor="w")
search_button = tk.Button(rating_buttons_frame, text="                                  搜尋                                     ", command=result)
search_button.pack(side=tk.LEFT, padx=5, pady=5, anchor="w")

# 建立評分篩選按鈕容器
rating_buttons_frame = tk.Frame(root)
rating_buttons_frame.pack(padx=5, pady=5, anchor="w")

# 建立評分篩選按鈕
location_label = tk.Label(rating_buttons_frame, text="篩選(以評分):")
location_label.pack(side=tk.LEFT, padx=5, pady=5, anchor="w")

search_button1 = tk.Button(rating_buttons_frame, text="4.5顆星星", command=rating_45)
search_button1.pack(side=tk.LEFT, padx=0, pady=5)

search_button2 = tk.Button(rating_buttons_frame, text="4.0顆星星", command=rating_40)
search_button2.pack(side=tk.LEFT, padx=52, pady=5)

search_button3 = tk.Button(rating_buttons_frame, text="3.5顆星星", command=rating_35)
search_button3.pack(side=tk.LEFT, padx=0, pady=5)

# 建立價格篩選按鈕容器
rating_buttons_frame = tk.Frame(root)
rating_buttons_frame.pack(padx=5, pady=5, anchor="w")

# 建立價格篩選按鈕
location_label = tk.Label(rating_buttons_frame, text="篩選(以CP值):")
location_label.pack(side=tk.LEFT, padx=5, pady=5, anchor="w")
search_button1 = tk.Button(rating_buttons_frame, text="  3(昂貴)  ", command=price_3)
search_button1.pack(side=tk.LEFT, padx=0, pady=5)
search_button2 = tk.Button(rating_buttons_frame, text="  2(中等)  ", command=price_2)
search_button2.pack(side=tk.LEFT, padx=52, pady=5)
search_button3 = tk.Button(rating_buttons_frame, text="  1(便宜)  ", command=price_1)
search_button3.pack(side=tk.LEFT, padx=0, pady=5)

# 建立結果列表框架
results_frame = tk.Frame(root)
results_frame.pack(padx=0, pady=5, fill=tk.BOTH, expand=True)

# 建立結果列表
results_listbox = tk.Listbox(results_frame, width=60, height=15)
results_listbox.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)
results_scrollbar = tk.Scrollbar(results_frame, orient=tk.VERTICAL, command=results_listbox.yview)
results_scrollbar.pack(side=tk.RIGHT, fill=tk.Y)
results_listbox.config(yscrollcommand=results_scrollbar.set)

# 啟動使用者介面
root.mainloop()
