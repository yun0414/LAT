# %%
# 想要

# %%
import pandas as pd

df = pd.read_csv("2014_08_10414-00-01-2_臺中市高級中等學校應屆畢業生升學就業概況.csv")

print(df.to_string())
# Out:
#              RptNo               RptName StatCourseNo               StatCourseName              DataDate      PlaceNo PlaceName PeriodNo PeriodName        Complex1      ComplexName      Complex2 Complex2Name    Complex3 Complex3Name  Complex4  Complex4Name  Complex5  Complex5Name  DeriveNo  DeriveExplain  FValue  SValue   RptDeptNo RptDeptName              CreateTime            ModifyTime
# 0    10414-00-01-2  臺中市高級中等學校應屆畢業生升學就業概況  1041400a003  高級中等學校應屆畢業生升學就業概況-畢業生(單位:人)  2014/8/1 上午 12:00:00  10000066000       臺中市        S         學年    230220000101         大學校院(大學)  230310000201          普通科  9900100001            男         0           NaN         0           NaN         0            NaN    6090     NaN  387040000E         教育局  2016/12/15 下午 06:27:36  2017/3/9 下午 01:20:32
# ...

# %%
df
# Out:
#              RptNo               RptName StatCourseNo  \
# 0    10414-00-01-2  臺中市高級中等學校應屆畢業生升學就業概況  1041400a003
# 1    10414-00-01-2  臺中市高級中等學校應屆畢業生升學就業概況  1041400a003
# 2    10414-00-01-2  臺中市高級中等學校應屆畢業生升學就業概況  1041400a003
# 3    10414-00-01-2  臺中市高級中等學校應屆畢業生升學就業概況  1041400a003
# 4    10414-00-01-2  臺中市高級中等學校應屆畢業生升學就業概況  1041400a003
# ..             ...                   ...          ...
# 675  10414-00-01-2  臺中市高級中等學校應屆畢業生升學就業概況  1041400a003
# 676  10414-00-01-2  臺中市高級中等學校應屆畢業生升學就業概況  1041400a003
# 677  10414-00-01-2  臺中市高級中等學校應屆畢業生升學就業概況  1041400a003
# 678  10414-00-01-2  臺中市高級中等學校應屆畢業生升學就業概況  1041400a003
# 679  10414-00-01-2  臺中市高級中等學校應屆畢業生升學就業概況  1041400a003
#
#                   StatCourseName              DataDate      PlaceNo PlaceName  \
# 0    高級中等學校應屆畢業生升學就業概況-畢業生(單位:人)  2014/8/1 上午 12:00:00  10000066000       臺中市
# 1    高級中等學校應屆畢業生升學就業概況-畢業生(單位:人)  2014/8/1 上午 12:00:00  10000066000       臺中市
# 2    高級中等學校應屆畢業生升學就業概況-畢業生(單位:人)  2014/8/1 上午 12:00:00  10000066000       臺中市
# ...
